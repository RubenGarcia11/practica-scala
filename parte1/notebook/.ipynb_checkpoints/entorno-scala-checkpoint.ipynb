// %%
val nombre = "Scala"
val version = "2.12.21"

println(s"Hola desde$nombre$version")
// Out:
// Hola desdeScala2.12.21
// nombre: String = "Scala"
// version: String = "2.12.21"

// %%
val a = 10
val b = 20
val resultado = a + b

println(resultado)
// Out:
// 30
// a: Int = 10
// b: Int = 20
// resultado: Int = 30

// %%
val lenguajes = List("Scala", "Java", "Python")

println(lenguajes)
// Out:
// List(Scala, Java, Python)
// lenguajes: List[String] = List("Scala", "Java", "Python")

// %%
scala.util.Properties.versionString
// Out:
// res4: String = "version 2.12.21"
